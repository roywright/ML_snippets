# %% [markdown]
# # Justifying a random forest's predictions
# ## Libraries and experimental data set

# %%
# Libraries to be used
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from lime.lime_tabular import LimeTabularExplainer
from scipy.sparse import hstack

# Hide warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Load data set for experiments
from sklearn.datasets import load_wine
dataset = load_wine()
X = pd.DataFrame(dataset.data, columns = dataset.feature_names)
y = dataset.target

# %%
# Split data into training and test sets
Xtrain, Xtest, ytrain, ytest = train_test_split(
    X, y,
    stratify = y,
    train_size = 100,
    random_state = 2018   # for reproducibility
)

# %% [markdown]
# ## Exploratory analysis and random forest classifiers

# %%
# Take a glance at feature distributions, broken down by class
Xtrain.groupby(ytrain).quantile([.1,.9])
# Out:
#        alcohol  malic_acid    ash  alcalinity_of_ash  magnesium  \
# 0 0.1   13.208       1.640  2.178               14.0       96.2
#   0.9   14.356       2.998  2.700               20.4      118.0
# 1 0.1   11.787       0.976  1.746               16.0       80.0
#   0.9   13.133       3.430  2.676               25.1      110.2
# 2 0.1   12.486       2.146  2.200               18.5       87.2
#   0.9   13.980       4.986  2.694               25.0      111.4
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0 0.1          2.600       2.618                 0.202            1.352
#   0.9          3.294       3.546                 0.340            2.380
# 1 0.1          1.450       1.250                 0.237            0.820
#   0.9          2.842       2.671                 0.532            1.992
# 2 0.1          1.322       0.522                 0.282            0.836
#   0.9          2.240       1.134                 0.618            1.560
#
#        color_intensity    hue  od280/od315_of_diluted_wines  proline
# 0 0.1            4.332  0.882                         2.754    845.0
#   0.9            7.250  1.224                         3.518   1474.0
# 1 0.1            1.950  0.898                         2.047    364.0
#   0.9            3.870  1.360                         3.217    710.8
# 2 0.1            4.912  0.566                         1.348    501.0
#   0.9           10.364  0.832                         1.976    832.0

# %%
# Train a random forest classifier for each of the three classes
clf = []
for clas in range(3):
    clf.append(
        RandomForestClassifier(
            n_estimators = 100, n_jobs = -1,
            random_state = 2018   # for reproducibility
        ).fit(Xtrain, ytrain == clas)
    )

# %%
# Check the AUC's of the classifiers on the test data
for clas in range(3):
    print(roc_auc_score(ytest == clas, clf[clas].predict_proba(Xtest)[:,1]))
# Out:
# 1.0
# 0.994509265614
# 1.0

# %% [markdown]
# ## Explanations from LIME

# %%
# Create a LIME explainer for tabular data
explainer = LimeTabularExplainer(
    Xtrain.values, feature_names = Xtrain.columns,
    random_state = 2018   # for reproducibility
)

def explain_row(clf, row, num_reasons = 2):
    '''
    Produce LIME explanations for a single row of data.
        * `clf` is a binary classifier (with a predict_proba method),
        * `row` is a row of features data,
        * `num_reasons` (default 2) is the number of 
          reasons/explanations to be produced.
          
    '''
    exp = [
        exp_pair[0] for exp_pair in     # Get each explanation (a string)
        explainer.explain_instance(     # from the LIME explainer
            row, clf.predict_proba,     # for the given row and classifier
            labels = [1],               # and label 1 ("positives")
            num_features = num_reasons  # for up to `num_reasons` explanations
        ).as_list()
        if exp_pair[1] > 0              # but only for positive explanations 
    ][:num_reasons]
    
    # Fill in any missing explanations with blanks
    exp += [''] * (num_reasons - len(exp))  
    return exp


def predict_explain(rf, X, num_reasons = 2):
    '''
    Produce scores and LIME explanations for every row in a data frame.
        * `rf` is a binary classifier with a predict_proba method,
        * `X` is the features data frame,
        * `num_reasons` (default 2) is the number of 
          reasons/explanations to be produced for each row.
          
    '''
    # Prepare the structure to be returned
    pred_ex = Xtest[[]]
    
    # Get the scores from the classifier
    pred_ex['SCORE'] = rf.predict_proba(X)[:,1]
    
    # Get the reasons/explanations for each row
    cols = zip(
        *Xtest.apply(
            lambda x: explain_row(rf, x, num_reasons), 
            axis = 1, raw = True
        )
    )
    
    # Return the results
    for n in range(num_reasons):
        pred_ex['REASON%d' % (n+1)] = next(cols)
    return pred_ex

# %% [markdown]
# ### Explanations for top cases predicted to belong to class 0

# %%
# %%time
pe0l = predict_explain(clf[0], Xtest).assign(
    TRUE_CLASS = ytest
).sort_values('SCORE', ascending = False).head(20)
# Out:
# Wall time: 44 s

# %%
pe0l
# Out:
#     SCORE            REASON1                       REASON2  TRUE_CLASS
# 58   1.00   proline > 973.75             flavanoids > 2.81           0
# 57   1.00   proline > 973.75             flavanoids > 2.81           0
# 0    1.00   proline > 973.75             flavanoids > 2.81           0
# 26   0.98   proline > 973.75             flavanoids > 2.81           0
# 49   0.98   proline > 973.75             flavanoids > 2.81           0
# 31   0.98   proline > 973.75             flavanoids > 2.81           0
# 51   0.96   proline > 973.75             flavanoids > 2.81           0
# 47   0.96   proline > 973.75             flavanoids > 2.81           0
# 9    0.95   proline > 973.75             flavanoids > 2.81           0
# 13   0.95   proline > 973.75             flavanoids > 2.81           0
# 7    0.95   proline > 973.75               alcohol > 13.74           0
# 28   0.94  flavanoids > 2.81          total_phenols > 2.80           0
# 20   0.92  flavanoids > 2.81          total_phenols > 2.80           0
# 17   0.91   proline > 973.75             flavanoids > 2.81           0
# 22   0.91   proline > 973.75             flavanoids > 2.81           0
# 6    0.90   proline > 973.75  2.21 < total_phenols <= 2.80           0
# 50   0.86   proline > 973.75             flavanoids > 2.81           0
# 32   0.81   proline > 973.75      13.13 < alcohol <= 13.74           0
# 41   0.80   proline > 973.75  2.21 < total_phenols <= 2.80           0
# 38   0.79   proline > 973.75  2.21 < total_phenols <= 2.80           0

# %% [markdown]
# ### Explanations for top cases predicted to belong to class 1

# %%
# %%time
pe1l = predict_explain(clf[1], Xtest).assign(
    TRUE_CLASS = ytest
).sort_values('SCORE', ascending = False).head(20)
# Out:
# Wall time: 45.4 s

# %%
pe1l
# Out:
#      SCORE                  REASON1             REASON2  TRUE_CLASS
# 128   1.00  color_intensity <= 3.14   proline <= 495.00           1
# 97    1.00  color_intensity <= 3.14   proline <= 495.00           1
# 86    1.00  color_intensity <= 3.14    alcohol <= 12.41           1
# 117   0.99  color_intensity <= 3.14   proline <= 495.00           1
# 113   0.99  color_intensity <= 3.14    alcohol <= 12.41           1
# 106   0.99         alcohol <= 12.41         ash <= 2.20           1
# 114   0.99  color_intensity <= 3.14   proline <= 495.00           1
# 78    0.98         alcohol <= 12.41  malic_acid <= 1.64           1
# 99    0.98  color_intensity <= 3.14   proline <= 495.00           1
# 94    0.98         alcohol <= 12.41   proline <= 495.00           1
# 108   0.98  color_intensity <= 3.14   proline <= 495.00           1
# 105   0.96  color_intensity <= 3.14   proline <= 495.00           1
# 88    0.94  color_intensity <= 3.14    alcohol <= 12.41           1
# 109   0.93  color_intensity <= 3.14    alcohol <= 12.41           1
# 110   0.93  color_intensity <= 3.14    alcohol <= 12.41           1
# 102   0.93  color_intensity <= 3.14   proline <= 495.00           1
# 74    0.91         alcohol <= 12.41  malic_acid <= 1.64           1
# 124   0.91  color_intensity <= 3.14   proline <= 495.00           1
# 104   0.90  color_intensity <= 3.14         ash <= 2.20           1
# 129   0.89  color_intensity <= 3.14    alcohol <= 12.41           1

# %% [markdown]
# ### Explanations for top cases predicted to belong to class 2

# %%
# %%time
pe2l = predict_explain(clf[2], Xtest).assign(
    TRUE_CLASS = ytest
).sort_values('SCORE', ascending = False).head(20)
# Out:
# Wall time: 45.1 s

# %%
pe2l
# Out:
#      SCORE             REASON1                               REASON2  \
# 176   1.00         hue <= 0.82                    flavanoids <= 1.01
# 155   1.00         hue <= 0.82                    flavanoids <= 1.01
# 174   1.00         hue <= 0.82                    flavanoids <= 1.01
# 148   0.98         hue <= 0.82                    flavanoids <= 1.01
# 169   0.94         hue <= 0.82                    flavanoids <= 1.01
# 163   0.94         hue <= 0.82                    flavanoids <= 1.01
# 171   0.91         hue <= 0.82                    flavanoids <= 1.01
# 131   0.90         hue <= 0.82  od280/od315_of_diluted_wines <= 1.85
# 170   0.85         hue <= 0.82                    flavanoids <= 1.01
# 136   0.81         hue <= 0.82                    flavanoids <= 1.01
# 149   0.81         hue <= 0.82  od280/od315_of_diluted_wines <= 1.85
# 159   0.80         hue <= 0.82  od280/od315_of_diluted_wines <= 1.85
# 150   0.79         hue <= 0.82  od280/od315_of_diluted_wines <= 1.85
# 151   0.77         hue <= 0.82  od280/od315_of_diluted_wines <= 1.85
# 154   0.75         hue <= 0.82                    flavanoids <= 1.01
# 140   0.72         hue <= 0.82                    flavanoids <= 1.01
# 162   0.67  flavanoids <= 1.01                     malic_acid > 3.15
# 142   0.67  flavanoids <= 1.01                     malic_acid > 3.15
# 141   0.66         hue <= 0.82                    flavanoids <= 1.01
# 130   0.62         hue <= 0.82  od280/od315_of_diluted_wines <= 1.85
#
#      TRUE_CLASS
# 176           2
# 155           2
# 174           2
# 148           2
# 169           2
# 163           2
# 171           2
# 131           2
# 170           2
# 136           2
# 149           2
# 159           2
# 150           2
# 151           2
# 154           2
# 140           2
# 162           2
# 142           2
# 141           2
# 130           2

# %% [markdown]
# ## Explanations by tree interpretation

# %%
import tree_explainer

# %% [markdown]
# ### Explanations for top cases predicted to belong to class 0

# %%
# %%time
pe0t = tree_explainer.predict_explain(clf[0], Xtest).assign(
    TRUE_CLASS = ytest
).sort_values('SCORE', ascending = False).head(20)
# Out:
# Wall time: 330 ms

# %%
pe0t
# Out:
#     SCORE                       REASON1                       REASON2  \
# 58   1.00             proline > 1010.00  2.57 < total_phenols <= 3.41
# 57   1.00             proline > 1010.00  2.57 < total_phenols <= 3.28
# 0    1.00             proline > 1010.00  2.57 < total_phenols <= 3.28
# 26   0.98             proline > 1010.00  2.57 < total_phenols <= 3.28
# 49   0.98             proline > 1045.00  2.66 < total_phenols <= 3.28
# 31   0.98             proline > 1045.00  2.66 < total_phenols <= 3.28
# 51   0.96             proline > 1082.50             flavanoids > 2.70
# 47   0.96              proline > 895.00  2.57 < total_phenols <= 3.28
# 9    0.95             proline > 1010.00  2.57 < total_phenols <= 3.28
# 13   0.95             proline > 1010.00             flavanoids > 2.70
# 7    0.95             proline > 1010.00  2.57 < total_phenols <= 3.28
# 28   0.94              proline > 895.00             flavanoids > 2.93
# 20   0.92  2.57 < total_phenols <= 3.28             flavanoids > 2.97
# 17   0.91             proline > 1122.50  2.66 < total_phenols <= 3.28
# 22   0.91             proline > 1010.00  2.57 < total_phenols <= 3.28
# 6    0.90             proline > 1082.50               alcohol > 13.38
# 50   0.86             proline > 1045.00  2.57 < total_phenols <= 3.28
# 32   0.81              proline > 970.00     2.67 < flavanoids <= 2.79
# 41   0.80             proline > 1010.00             flavanoids > 2.66
# 38   0.79             proline > 1017.50             flavanoids > 2.62
#
#     TRUE_CLASS
# 58           0
# 57           0
# 0            0
# 26           0
# 49           0
# 31           0
# 51           0
# 47           0
# 9            0
# 13           0
# 7            0
# 28           0
# 20           0
# 17           0
# 22           0
# 6            0
# 50           0
# 32           0
# 41           0
# 38           0

# %% [markdown]
# ### Explanations for top cases predicted to belong to class 1

# %%
# %%time
pe1t = tree_explainer.predict_explain(clf[1], Xtest).assign(
    TRUE_CLASS = ytest
).sort_values('SCORE', ascending = False).head(20)
# Out:
# Wall time: 288 ms

# %%
pe1t
# Out:
#      SCORE                  REASON1                   REASON2  TRUE_CLASS
# 128   1.00  color_intensity <= 3.26         proline <= 375.00           1
# 97    1.00  color_intensity <= 3.43         proline <= 505.00           1
# 86    1.00  color_intensity <= 3.22  12.16 < alcohol <= 12.21           1
# 117   0.99  color_intensity <= 3.43         proline <= 375.00           1
# 113   0.99  color_intensity <= 3.43         proline <= 476.00           1
# 106   0.99  color_intensity <= 3.43          alcohol <= 12.32           1
# 114   0.99  color_intensity <= 3.43         proline <= 476.00           1
# 78    0.98  color_intensity <= 3.43          alcohol <= 12.37           1
# 99    0.98  color_intensity <= 3.28         proline <= 476.00           1
# 94    0.98  color_intensity <= 3.28          alcohol <= 12.16           1
# 108   0.98  color_intensity <= 3.43         proline <= 430.00           1
# 105   0.96  color_intensity <= 3.26         proline <= 375.00           1
# 88    0.94  color_intensity <= 3.35          alcohol <= 12.16           1
# 109   0.93  color_intensity <= 3.22          alcohol <= 12.06           1
# 110   0.93  color_intensity <= 3.22          alcohol <= 12.16           1
# 102   0.93  color_intensity <= 3.26         proline <= 446.00           1
# 74    0.91  color_intensity <= 3.22          alcohol <= 12.06           1
# 124   0.91  color_intensity <= 3.41         proline <= 430.00           1
# 104   0.90  color_intensity <= 3.43          alcohol <= 12.65           1
# 129   0.89  color_intensity <= 3.43          alcohol <= 12.16           1

# %% [markdown]
# ### Explanations for top cases predicted to belong to class 2

# %%
# %%time
pe2t = tree_explainer.predict_explain(clf[2], Xtest).assign(
    TRUE_CLASS = ytest
).sort_values('SCORE', ascending = False).head(20)
# Out:
# Wall time: 274 ms

# %%
pe2t
# Out:
#      SCORE                               REASON1  \
# 176   1.00                           hue <= 0.80
# 155   1.00                           hue <= 0.80
# 174   1.00                           hue <= 0.80
# 148   0.98                           hue <= 0.80
# 169   0.94                           hue <= 0.76
# 163   0.94                           hue <= 0.70
# 171   0.91                           hue <= 0.80
# 131   0.90                           hue <= 0.76
# 170   0.85                           hue <= 0.70
# 136   0.81                           hue <= 0.84
# 149   0.81                           hue <= 0.76
# 159   0.80                           hue <= 0.76
# 150   0.79                           hue <= 0.76
# 151   0.77  od280/od315_of_diluted_wines <= 1.48
# 154   0.75                           hue <= 0.80
# 140   0.72                           hue <= 0.81
# 162   0.67             0.59 < flavanoids <= 0.89
# 142   0.67                    flavanoids <= 0.81
# 141   0.66                           hue <= 0.81
# 130   0.62                           hue <= 0.81
#
#                                          REASON2  TRUE_CLASS
# 176                           flavanoids <= 0.85           2
# 155         od280/od315_of_diluted_wines <= 1.78           2
# 174         od280/od315_of_diluted_wines <= 1.78           2
# 148         od280/od315_of_diluted_wines <= 1.78           2
# 169         od280/od315_of_diluted_wines <= 2.01           2
# 163                           flavanoids <= 0.89           2
# 171  1.63 < od280/od315_of_diluted_wines <= 1.78           2
# 131         od280/od315_of_diluted_wines <= 1.48           2
# 170                           flavanoids <= 0.89           2
# 136                           flavanoids <= 0.89           2
# 149         od280/od315_of_diluted_wines <= 1.48           2
# 159  1.78 < od280/od315_of_diluted_wines <= 1.79           2
# 150         od280/od315_of_diluted_wines <= 1.48           2
# 151                                  hue <= 0.76           2
# 154         od280/od315_of_diluted_wines <= 1.63           2
# 140                           flavanoids <= 0.85           2
# 162                            malic_acid > 2.93           2
# 142                            malic_acid > 2.93           2
# 141                           flavanoids <= 0.85           2
# 130         od280/od315_of_diluted_wines <= 1.48           2

# %% [markdown]
# ## Comparing the systems

# %% [markdown]
# ### For class 0

# %%
pe0l[['REASON1','REASON2']].join(
    pe0t[['REASON1','REASON2']], 
    lsuffix = '_LIME'
)
# Out:
#          REASON1_LIME                  REASON2_LIME  \
# 58   proline > 973.75             flavanoids > 2.81
# 57   proline > 973.75             flavanoids > 2.81
# 0    proline > 973.75             flavanoids > 2.81
# 26   proline > 973.75             flavanoids > 2.81
# 49   proline > 973.75             flavanoids > 2.81
# 31   proline > 973.75             flavanoids > 2.81
# 51   proline > 973.75             flavanoids > 2.81
# 47   proline > 973.75             flavanoids > 2.81
# 9    proline > 973.75             flavanoids > 2.81
# 13   proline > 973.75             flavanoids > 2.81
# 7    proline > 973.75               alcohol > 13.74
# 28  flavanoids > 2.81          total_phenols > 2.80
# 20  flavanoids > 2.81          total_phenols > 2.80
# 17   proline > 973.75             flavanoids > 2.81
# 22   proline > 973.75             flavanoids > 2.81
# 6    proline > 973.75  2.21 < total_phenols <= 2.80
# 50   proline > 973.75             flavanoids > 2.81
# 32   proline > 973.75      13.13 < alcohol <= 13.74
# 41   proline > 973.75  2.21 < total_phenols <= 2.80
# 38   proline > 973.75  2.21 < total_phenols <= 2.80
#
#                          REASON1                       REASON2
# 58             proline > 1010.00  2.57 < total_phenols <= 3.41
# 57             proline > 1010.00  2.57 < total_phenols <= 3.28
# 0              proline > 1010.00  2.57 < total_phenols <= 3.28
# 26             proline > 1010.00  2.57 < total_phenols <= 3.28
# 49             proline > 1045.00  2.66 < total_phenols <= 3.28
# 31             proline > 1045.00  2.66 < total_phenols <= 3.28
# 51             proline > 1082.50             flavanoids > 2.70
# 47              proline > 895.00  2.57 < total_phenols <= 3.28
# 9              proline > 1010.00  2.57 < total_phenols <= 3.28
# 13             proline > 1010.00             flavanoids > 2.70
# 7              proline > 1010.00  2.57 < total_phenols <= 3.28
# 28              proline > 895.00             flavanoids > 2.93
# 20  2.57 < total_phenols <= 3.28             flavanoids > 2.97
# 17             proline > 1122.50  2.66 < total_phenols <= 3.28
# 22             proline > 1010.00  2.57 < total_phenols <= 3.28
# 6              proline > 1082.50               alcohol > 13.38
# 50             proline > 1045.00  2.57 < total_phenols <= 3.28
# 32              proline > 970.00     2.67 < flavanoids <= 2.79
# 41             proline > 1010.00             flavanoids > 2.66
# 38             proline > 1017.50             flavanoids > 2.62

# %% [markdown]
# ### For class 1

# %%
pe1l[['REASON1','REASON2']].join(
    pe1t[['REASON1','REASON2']], 
    lsuffix = '_LIME'
)
# Out:
#                 REASON1_LIME        REASON2_LIME                  REASON1  \
# 128  color_intensity <= 3.14   proline <= 495.00  color_intensity <= 3.26
# 97   color_intensity <= 3.14   proline <= 495.00  color_intensity <= 3.43
# 86   color_intensity <= 3.14    alcohol <= 12.41  color_intensity <= 3.22
# 117  color_intensity <= 3.14   proline <= 495.00  color_intensity <= 3.43
# 113  color_intensity <= 3.14    alcohol <= 12.41  color_intensity <= 3.43
# 106         alcohol <= 12.41         ash <= 2.20  color_intensity <= 3.43
# 114  color_intensity <= 3.14   proline <= 495.00  color_intensity <= 3.43
# 78          alcohol <= 12.41  malic_acid <= 1.64  color_intensity <= 3.43
# 99   color_intensity <= 3.14   proline <= 495.00  color_intensity <= 3.28
# 94          alcohol <= 12.41   proline <= 495.00  color_intensity <= 3.28
# 108  color_intensity <= 3.14   proline <= 495.00  color_intensity <= 3.43
# 105  color_intensity <= 3.14   proline <= 495.00  color_intensity <= 3.26
# 88   color_intensity <= 3.14    alcohol <= 12.41  color_intensity <= 3.35
# 109  color_intensity <= 3.14    alcohol <= 12.41  color_intensity <= 3.22
# 110  color_intensity <= 3.14    alcohol <= 12.41  color_intensity <= 3.22
# 102  color_intensity <= 3.14   proline <= 495.00  color_intensity <= 3.26
# 74          alcohol <= 12.41  malic_acid <= 1.64  color_intensity <= 3.22
# 124  color_intensity <= 3.14   proline <= 495.00  color_intensity <= 3.41
# 104  color_intensity <= 3.14         ash <= 2.20  color_intensity <= 3.43
# 129  color_intensity <= 3.14    alcohol <= 12.41  color_intensity <= 3.43
#
#                       REASON2
# 128         proline <= 375.00
# 97          proline <= 505.00
# 86   12.16 < alcohol <= 12.21
# 117         proline <= 375.00
# 113         proline <= 476.00
# 106          alcohol <= 12.32
# 114         proline <= 476.00
# 78           alcohol <= 12.37
# 99          proline <= 476.00
# 94           alcohol <= 12.16
# 108         proline <= 430.00
# 105         proline <= 375.00
# 88           alcohol <= 12.16
# 109          alcohol <= 12.06
# 110          alcohol <= 12.16
# 102         proline <= 446.00
# 74           alcohol <= 12.06
# 124         proline <= 430.00
# 104          alcohol <= 12.65
# 129          alcohol <= 12.16

# %% [markdown]
# ### For class 2

# %%
pe2l[['REASON1','REASON2']].join(
    pe2t[['REASON1','REASON2']], 
    lsuffix = '_LIME'
)
# Out:
#            REASON1_LIME                          REASON2_LIME  \
# 176         hue <= 0.82                    flavanoids <= 1.01
# 155         hue <= 0.82                    flavanoids <= 1.01
# 174         hue <= 0.82                    flavanoids <= 1.01
# 148         hue <= 0.82                    flavanoids <= 1.01
# 169         hue <= 0.82                    flavanoids <= 1.01
# 163         hue <= 0.82                    flavanoids <= 1.01
# 171         hue <= 0.82                    flavanoids <= 1.01
# 131         hue <= 0.82  od280/od315_of_diluted_wines <= 1.85
# 170         hue <= 0.82                    flavanoids <= 1.01
# 136         hue <= 0.82                    flavanoids <= 1.01
# 149         hue <= 0.82  od280/od315_of_diluted_wines <= 1.85
# 159         hue <= 0.82  od280/od315_of_diluted_wines <= 1.85
# 150         hue <= 0.82  od280/od315_of_diluted_wines <= 1.85
# 151         hue <= 0.82  od280/od315_of_diluted_wines <= 1.85
# 154         hue <= 0.82                    flavanoids <= 1.01
# 140         hue <= 0.82                    flavanoids <= 1.01
# 162  flavanoids <= 1.01                     malic_acid > 3.15
# 142  flavanoids <= 1.01                     malic_acid > 3.15
# 141         hue <= 0.82                    flavanoids <= 1.01
# 130         hue <= 0.82  od280/od315_of_diluted_wines <= 1.85
#
#                                   REASON1  \
# 176                           hue <= 0.80
# 155                           hue <= 0.80
# 174                           hue <= 0.80
# 148                           hue <= 0.80
# 169                           hue <= 0.76
# 163                           hue <= 0.70
# 171                           hue <= 0.80
# 131                           hue <= 0.76
# 170                           hue <= 0.70
# 136                           hue <= 0.84
# 149                           hue <= 0.76
# 159                           hue <= 0.76
# 150                           hue <= 0.76
# 151  od280/od315_of_diluted_wines <= 1.48
# 154                           hue <= 0.80
# 140                           hue <= 0.81
# 162             0.59 < flavanoids <= 0.89
# 142                    flavanoids <= 0.81
# 141                           hue <= 0.81
# 130                           hue <= 0.81
#
#                                          REASON2
# 176                           flavanoids <= 0.85
# 155         od280/od315_of_diluted_wines <= 1.78
# 174         od280/od315_of_diluted_wines <= 1.78
# 148         od280/od315_of_diluted_wines <= 1.78
# 169         od280/od315_of_diluted_wines <= 2.01
# 163                           flavanoids <= 0.89
# 171  1.63 < od280/od315_of_diluted_wines <= 1.78
# 131         od280/od315_of_diluted_wines <= 1.48
# 170                           flavanoids <= 0.89
# 136                           flavanoids <= 0.89
# 149         od280/od315_of_diluted_wines <= 1.48
# 159  1.78 < od280/od315_of_diluted_wines <= 1.79
# 150         od280/od315_of_diluted_wines <= 1.48
# 151                                  hue <= 0.76
# 154         od280/od315_of_diluted_wines <= 1.63
# 140                           flavanoids <= 0.85
# 162                            malic_acid > 2.93
# 142                            malic_acid > 2.93
# 141                           flavanoids <= 0.85
# 130         od280/od315_of_diluted_wines <= 1.48
