# %% [markdown]
# # Justifying a random forest's predictions
# ## Libraries and experimental data set

# %%
# Libraries to be used
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from lime.lime_tabular import LimeTabularExplainer
from scipy.sparse import hstack

# Hide warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Load data set for experiments
from sklearn.datasets import load_wine
dataset = load_wine()
X = pd.DataFrame(dataset.data, columns = dataset.feature_names)
y = dataset.target

# %%
# Split data into training and test sets
Xtrain, Xtest, ytrain, ytest = train_test_split(
    X, y,
    stratify = y,
    train_size = 100,
    random_state = 2017   # for reproducibility
)

# %% [markdown]
# ## Exploratory analysis and random forest classifiers

# %%
# Take a glance at feature distributions, broken down by class
Xtrain.groupby(ytrain).quantile([.1,.9])
# Out:
#        alcohol  malic_acid    ash  alcalinity_of_ash  magnesium  \
# 0 0.1   13.050       1.538  2.222              14.40       94.2
#   0.9   14.218       3.758  2.700              20.40      119.6
# 1 0.1   11.637       0.976  1.813              16.80       83.6
#   0.9   13.032       2.944  2.673              22.61      110.2
# 2 0.1   12.486       1.812  2.242              19.10       86.0
#   0.9   13.980       4.654  2.716              25.00      112.4
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0 0.1          2.412       2.414                 0.220            1.368
#   0.9          3.200       3.512                 0.398            2.380
# 1 0.1          1.648       1.277                 0.208            0.820
#   0.9          2.905       2.797                 0.532            2.121
# 2 0.1          1.292       0.494                 0.266            0.818
#   0.9          2.240       1.292                 0.610            1.684
#
#        color_intensity    hue  od280/od315_of_diluted_wines  proline
# 0 0.1            3.858  0.890                         2.718    782.0
#   0.9            6.760  1.224                         3.578   1285.0
# 1 0.1            1.995  0.786                         2.101    340.3
#   0.9            3.991  1.288                         3.300    721.2
# 2 0.1            5.200  0.556                         1.330    476.0
#   0.9           10.632  0.750                         1.884    782.0

# %%
# Train a random forest classifier for each of the three classes
clf = []
for clas in range(3):
    clf.append(
        RandomForestClassifier(
            n_estimators = 100, n_jobs = -1,
            random_state = 2017   # for reproducibility
        ).fit(Xtrain, ytrain == clas)
    )

# %%
# Check the AUC's of the classifiers on the test data
for clas in range(3):
    print(roc_auc_score(ytest == clas, clf[clas].predict_proba(Xtest)[:,1]))
# Out:
# 1.0
# 0.997597803706
# 1.0

# %% [markdown]
# ## Explanations from LIME

# %%
# Create a LIME explainer for tabular data
explainer = LimeTabularExplainer(
    Xtrain.values, feature_names = Xtrain.columns,
    random_state = 2017   # for reproducibility
)

def explain_row(clf, row, num_reasons = 2):
    '''
    Produce LIME explanations for a single row of data.
        * `clf` is a binary classifier (with a predict_proba method),
        * `row` is a row of features data,
        * `num_reasons` (default 2) is the number of 
          reasons/explanations to be produced.
          
    '''
    exp = [
        exp_pair[0] for exp_pair in     # Get each explanation (a string)
        explainer.explain_instance(     # from the LIME explainer
            row, clf.predict_proba,     # for the given row and classifier
            labels = [1],               # and label 1 ("positives")
            num_features = num_reasons  # for up to `num_reasons` explanations
        ).as_list()
        if exp_pair[1] > 0              # but only for positive explanations 
    ][:num_reasons]
    
    # Fill in any missing explanations with blanks
    exp += [''] * (num_reasons - len(exp))  
    return exp


def predict_explain(rf, X, num_reasons = 2):
    '''
    Produce scores and LIME explanations for every row in a data frame.
        * `rf` is a binary classifier with a predict_proba method,
        * `X` is the features data frame,
        * `num_reasons` (default 2) is the number of 
          reasons/explanations to be produced for each row.
          
    '''
    # Prepare the structure to be returned
    pred_ex = Xtest[[]]
    
    # Get the scores from the classifier
    pred_ex['SCORE'] = rf.predict_proba(X)[:,1]
    
    # Get the reasons/explanations for each row
    cols = zip(
        *Xtest.apply(
            lambda x: explain_row(rf, x, num_reasons), 
            axis = 1, raw = True
        )
    )
    
    # Return the results
    for n in range(num_reasons):
        pred_ex['REASON%d' % (n+1)] = next(cols)
    return pred_ex

# %% [markdown]
# ### Explanations for top cases predicted to belong to class 0

# %%
# %%time
pe0l = predict_explain(clf[0], Xtest).assign(
    TRUE_CLASS = ytest
).sort_values('SCORE', ascending = False).head(20)
# Out:
# Wall time: 41.2 s

# %%
pe0l
# Out:
#     SCORE            REASON1                              REASON2  TRUE_CLASS
# 53   1.00   proline > 996.25                    flavanoids > 2.70           0
# 0    1.00   proline > 996.25                    flavanoids > 2.70           0
# 56   1.00  flavanoids > 2.70                      alcohol > 13.69           0
# 3    1.00   proline > 996.25                    flavanoids > 2.70           0
# 18   1.00   proline > 996.25                    flavanoids > 2.70           0
# 15   1.00   proline > 996.25                    flavanoids > 2.70           0
# 5    1.00   proline > 996.25                    flavanoids > 2.70           0
# 8    0.99   proline > 996.25                    flavanoids > 2.70           0
# 42   0.98   proline > 996.25                    flavanoids > 2.70           0
# 47   0.98  flavanoids > 2.70                 total_phenols > 2.74           0
# 31   0.97   proline > 996.25                    flavanoids > 2.70           0
# 2    0.97   proline > 996.25                    flavanoids > 2.70           0
# 7    0.96   proline > 996.25                      alcohol > 13.69           0
# 6    0.96   proline > 996.25                      alcohol > 13.69           0
# 54   0.95   proline > 996.25                    flavanoids > 2.70           0
# 20   0.95  flavanoids > 2.70                      alcohol > 13.69           0
# 28   0.94  flavanoids > 2.70                      alcohol > 13.69           0
# 19   0.93  flavanoids > 2.70  od280/od315_of_diluted_wines > 3.16           0
# 9    0.92   proline > 996.25                    flavanoids > 2.70           0
# 40   0.92  flavanoids > 2.70                 total_phenols > 2.74           0

# %% [markdown]
# ### Explanations for top cases predicted to belong to class 1

# %%
# %%time
pe1l = predict_explain(clf[1], Xtest).assign(
    TRUE_CLASS = ytest
).sort_values('SCORE', ascending = False).head(20)
# Out:
# Wall time: 43 s

# %%
pe1l
# Out:
#      SCORE                  REASON1             REASON2  TRUE_CLASS
# 87    1.00  color_intensity <= 3.14    alcohol <= 12.37           1
# 86    1.00  color_intensity <= 3.14    alcohol <= 12.37           1
# 113   1.00  color_intensity <= 3.14    alcohol <= 12.37           1
# 82    1.00  color_intensity <= 3.14    alcohol <= 12.37           1
# 117   0.99  color_intensity <= 3.14   proline <= 507.50           1
# 94    0.99         alcohol <= 12.37   proline <= 507.50           1
# 99    0.99  color_intensity <= 3.14    alcohol <= 12.37           1
# 119   0.99  color_intensity <= 3.14    alcohol <= 12.37           1
# 101   0.99  color_intensity <= 3.14  malic_acid <= 1.56           1
# 108   0.99  color_intensity <= 3.14    alcohol <= 12.37           1
# 84    0.99  color_intensity <= 3.14    alcohol <= 12.37           1
# 90    0.98  color_intensity <= 3.14    alcohol <= 12.37           1
# 125   0.98  color_intensity <= 3.14    alcohol <= 12.37           1
# 97    0.97  color_intensity <= 3.14    alcohol <= 12.37           1
# 78    0.96         alcohol <= 12.37  malic_acid <= 1.56           1
# 102   0.96  color_intensity <= 3.14    alcohol <= 12.37           1
# 124   0.95  color_intensity <= 3.14    alcohol <= 12.37           1
# 122   0.92  color_intensity <= 3.14   proline <= 507.50           1
# 92    0.92  color_intensity <= 3.14  malic_acid <= 1.56           1
# 67    0.92         alcohol <= 12.37                               1

# %% [markdown]
# ### Explanations for top cases predicted to belong to class 2

# %%
# %%time
pe2l = predict_explain(clf[2], Xtest).assign(
    TRUE_CLASS = ytest
).sort_values('SCORE', ascending = False).head(20)
# Out:
# Wall time: 40.3 s

# %%
pe2l
# Out:
#      SCORE                               REASON1                REASON2  \
# 167   1.00  od280/od315_of_diluted_wines <= 1.82            hue <= 0.74
# 176   0.99  od280/od315_of_diluted_wines <= 1.82            hue <= 0.74
# 156   0.98  od280/od315_of_diluted_wines <= 1.82            hue <= 0.74
# 173   0.98  od280/od315_of_diluted_wines <= 1.82            hue <= 0.74
# 174   0.98  od280/od315_of_diluted_wines <= 1.82            hue <= 0.74
# 163   0.94  od280/od315_of_diluted_wines <= 1.82            hue <= 0.74
# 170   0.86                           hue <= 0.74     flavanoids <= 1.19
# 133   0.84  od280/od315_of_diluted_wines <= 1.82      malic_acid > 2.92
# 154   0.84  od280/od315_of_diluted_wines <= 1.82            hue <= 0.74
# 150   0.84  od280/od315_of_diluted_wines <= 1.82            hue <= 0.74
# 144   0.80                           hue <= 0.74     flavanoids <= 1.19
# 137   0.80  od280/od315_of_diluted_wines <= 1.82     flavanoids <= 1.19
# 166   0.78  od280/od315_of_diluted_wines <= 1.82     flavanoids <= 1.19
# 138   0.78  od280/od315_of_diluted_wines <= 1.82     flavanoids <= 1.19
# 130   0.76  od280/od315_of_diluted_wines <= 1.82  total_phenols <= 1.79
# 142   0.65                    flavanoids <= 1.19
# 161   0.60  od280/od315_of_diluted_wines <= 1.82     flavanoids <= 1.19
# 140   0.59                    flavanoids <= 1.19
# 141   0.57                           hue <= 0.74     flavanoids <= 1.19
# 143   0.47                    flavanoids <= 1.19
#
#      TRUE_CLASS
# 167           2
# 176           2
# 156           2
# 173           2
# 174           2
# 163           2
# 170           2
# 133           2
# 154           2
# 150           2
# 144           2
# 137           2
# 166           2
# 138           2
# 130           2
# 142           2
# 161           2
# 140           2
# 141           2
# 143           2

# %% [markdown]
# ## Explanations by tree interpretation

# %%
import tree_explainer

# %% [markdown]
# ### Explanations for top cases predicted to belong to class 0

# %%
# %%time
pe0t = tree_explainer.predict_explain(clf[0], Xtest).assign(
    TRUE_CLASS = ytest
).sort_values('SCORE', ascending = False).head(20)
# Out:
# Wall time: 262 ms

# %%
pe0t
# Out:
#     SCORE            REASON1                              REASON2  TRUE_CLASS
# 53   1.00   proline > 976.00                    flavanoids > 2.61           0
# 0    1.00   proline > 976.00                    flavanoids > 2.61           0
# 56   1.00   proline > 963.50                    flavanoids > 2.93           0
# 3    1.00  proline > 1003.00                    flavanoids > 2.93           0
# 18   1.00   proline > 976.00                    flavanoids > 2.61           0
# 15   1.00   proline > 976.00                    flavanoids > 2.61           0
# 5    1.00   proline > 976.00                    flavanoids > 2.61           0
# 8    0.99   proline > 976.00                    flavanoids > 2.61           0
# 42   0.98  proline > 1003.00                    flavanoids > 2.93           0
# 47   0.98   proline > 983.00                    flavanoids > 2.93           0
# 31   0.97   proline > 976.00                    flavanoids > 3.12           0
# 2    0.97  proline > 1021.00                    flavanoids > 2.61           0
# 7    0.96   proline > 976.00                    flavanoids > 2.34           0
# 6    0.96   proline > 976.00                    flavanoids > 2.34           0
# 54   0.95  proline > 1003.00                    flavanoids > 2.61           0
# 20   0.95  flavanoids > 2.61  od280/od315_of_diluted_wines > 3.45           0
# 28   0.94  flavanoids > 2.61  od280/od315_of_diluted_wines > 3.32           0
# 19   0.93  flavanoids > 2.93         2.63 < total_phenols <= 2.72           0
# 9    0.92   proline > 976.00                    flavanoids > 2.61           0
# 40   0.92  flavanoids > 2.93                      alcohol > 13.49           0

# %% [markdown]
# ### Explanations for top cases predicted to belong to class 1

# %%
# %%time
pe1t = tree_explainer.predict_explain(clf[1], Xtest).assign(
    TRUE_CLASS = ytest
).sort_values('SCORE', ascending = False).head(20)
# Out:
# Wall time: 267 ms

# %%
pe1t
# Out:
#      SCORE                  REASON1           REASON2  TRUE_CLASS
# 87    1.00  color_intensity <= 3.38  alcohol <= 12.15           1
# 86    1.00  color_intensity <= 3.38  alcohol <= 12.23           1
# 113   1.00  color_intensity <= 3.38  alcohol <= 12.44           1
# 82    1.00  color_intensity <= 3.38  alcohol <= 12.44           1
# 117   0.99  color_intensity <= 3.14  alcohol <= 12.44           1
# 94    0.99  color_intensity <= 3.38  alcohol <= 12.23           1
# 99    0.99  color_intensity <= 3.38  alcohol <= 12.44           1
# 119   0.99  color_intensity <= 3.38  alcohol <= 12.06           1
# 101   0.99  color_intensity <= 3.09  alcohol <= 12.72           1
# 108   0.99  color_intensity <= 3.41  alcohol <= 12.23           1
# 84    0.99  color_intensity <= 3.38  alcohol <= 12.23           1
# 90    0.98  color_intensity <= 3.38  alcohol <= 12.44           1
# 125   0.98  color_intensity <= 3.38  alcohol <= 12.44           1
# 97    0.97  color_intensity <= 3.41  alcohol <= 12.44           1
# 78    0.96  color_intensity <= 3.41  alcohol <= 12.41           1
# 102   0.96  color_intensity <= 3.14  alcohol <= 12.41           1
# 124   0.95  color_intensity <= 3.38  alcohol <= 12.44           1
# 122   0.92  color_intensity <= 3.14  alcohol <= 12.44           1
# 92    0.92  color_intensity <= 3.09  alcohol <= 12.72           1
# 67    0.92       malic_acid <= 1.18  alcohol <= 12.41           1

# %% [markdown]
# ### Explanations for top cases predicted to belong to class 2

# %%
# %%time
pe2t = tree_explainer.predict_explain(clf[2], Xtest).assign(
    TRUE_CLASS = ytest
).sort_values('SCORE', ascending = False).head(20)
# Out:
# Wall time: 240 ms

# %%
pe2t
# Out:
#      SCORE                               REASON1  \
# 167   1.00  od280/od315_of_diluted_wines <= 1.78
# 176   0.99  od280/od315_of_diluted_wines <= 1.78
# 156   0.98  od280/od315_of_diluted_wines <= 1.78
# 173   0.98  od280/od315_of_diluted_wines <= 1.78
# 174   0.98  od280/od315_of_diluted_wines <= 1.78
# 163   0.94  od280/od315_of_diluted_wines <= 1.78
# 170   0.86                           hue <= 0.74
# 133   0.84  od280/od315_of_diluted_wines <= 1.48
# 154   0.84                           hue <= 0.65
# 150   0.84  od280/od315_of_diluted_wines <= 1.53
# 144   0.80                           hue <= 0.74
# 137   0.80  od280/od315_of_diluted_wines <= 1.78
# 166   0.78  od280/od315_of_diluted_wines <= 1.78
# 138   0.78                    flavanoids <= 0.80
# 130   0.76  od280/od315_of_diluted_wines <= 1.48
# 142   0.65             0.52 < flavanoids <= 0.56
# 161   0.60                    flavanoids <= 0.80
# 140   0.59                    flavanoids <= 0.52
# 141   0.57                           hue <= 0.74
# 143   0.47                    flavanoids <= 0.81
#
#                                   REASON2  TRUE_CLASS
# 167                           hue <= 0.74           2
# 176                           hue <= 0.65           2
# 156                           hue <= 0.65           2
# 173                           hue <= 0.74           2
# 174                           hue <= 0.74           2
# 163                           hue <= 0.74           2
# 170  od280/od315_of_diluted_wines <= 1.88           2
# 133                           hue <= 0.78           2
# 154  od280/od315_of_diluted_wines <= 1.59           2
# 150                           hue <= 0.63           2
# 144                    flavanoids <= 0.80           2
# 137                    flavanoids <= 0.80           2
# 166                color_intensity > 7.57           2
# 138  od280/od315_of_diluted_wines <= 1.88           2
# 130                           hue <= 0.77           2
# 142  od280/od315_of_diluted_wines <= 2.10           2
# 161  od280/od315_of_diluted_wines <= 1.92           2
# 140                    0.77 < hue <= 0.77           2
# 141                    flavanoids <= 0.80           2
# 143  od280/od315_of_diluted_wines <= 2.10           2

# %% [markdown]
# ## Comparing the systems

# %% [markdown]
# ### For class 0

# %%
pe0l[['REASON1','REASON2']].join(
    pe0t[['REASON1','REASON2']], 
    lsuffix = '_LIME'
)
# Out:
#          REASON1_LIME                         REASON2_LIME            REASON1  \
# 53   proline > 996.25                    flavanoids > 2.70   proline > 976.00
# 0    proline > 996.25                    flavanoids > 2.70   proline > 976.00
# 56  flavanoids > 2.70                      alcohol > 13.69   proline > 963.50
# 3    proline > 996.25                    flavanoids > 2.70  proline > 1003.00
# 18   proline > 996.25                    flavanoids > 2.70   proline > 976.00
# 15   proline > 996.25                    flavanoids > 2.70   proline > 976.00
# 5    proline > 996.25                    flavanoids > 2.70   proline > 976.00
# 8    proline > 996.25                    flavanoids > 2.70   proline > 976.00
# 42   proline > 996.25                    flavanoids > 2.70  proline > 1003.00
# 47  flavanoids > 2.70                 total_phenols > 2.74   proline > 983.00
# 31   proline > 996.25                    flavanoids > 2.70   proline > 976.00
# 2    proline > 996.25                    flavanoids > 2.70  proline > 1021.00
# 7    proline > 996.25                      alcohol > 13.69   proline > 976.00
# 6    proline > 996.25                      alcohol > 13.69   proline > 976.00
# 54   proline > 996.25                    flavanoids > 2.70  proline > 1003.00
# 20  flavanoids > 2.70                      alcohol > 13.69  flavanoids > 2.61
# 28  flavanoids > 2.70                      alcohol > 13.69  flavanoids > 2.61
# 19  flavanoids > 2.70  od280/od315_of_diluted_wines > 3.16  flavanoids > 2.93
# 9    proline > 996.25                    flavanoids > 2.70   proline > 976.00
# 40  flavanoids > 2.70                 total_phenols > 2.74  flavanoids > 2.93
#
#                                 REASON2
# 53                    flavanoids > 2.61
# 0                     flavanoids > 2.61
# 56                    flavanoids > 2.93
# 3                     flavanoids > 2.93
# 18                    flavanoids > 2.61
# 15                    flavanoids > 2.61
# 5                     flavanoids > 2.61
# 8                     flavanoids > 2.61
# 42                    flavanoids > 2.93
# 47                    flavanoids > 2.93
# 31                    flavanoids > 3.12
# 2                     flavanoids > 2.61
# 7                     flavanoids > 2.34
# 6                     flavanoids > 2.34
# 54                    flavanoids > 2.61
# 20  od280/od315_of_diluted_wines > 3.45
# 28  od280/od315_of_diluted_wines > 3.32
# 19         2.63 < total_phenols <= 2.72
# 9                     flavanoids > 2.61
# 40                      alcohol > 13.49

# %% [markdown]
# ### For class 1

# %%
pe1l[['REASON1','REASON2']].join(
    pe1t[['REASON1','REASON2']], 
    lsuffix = '_LIME'
)
# Out:
#                 REASON1_LIME        REASON2_LIME                  REASON1  \
# 87   color_intensity <= 3.14    alcohol <= 12.37  color_intensity <= 3.38
# 86   color_intensity <= 3.14    alcohol <= 12.37  color_intensity <= 3.38
# 113  color_intensity <= 3.14    alcohol <= 12.37  color_intensity <= 3.38
# 82   color_intensity <= 3.14    alcohol <= 12.37  color_intensity <= 3.38
# 117  color_intensity <= 3.14   proline <= 507.50  color_intensity <= 3.14
# 94          alcohol <= 12.37   proline <= 507.50  color_intensity <= 3.38
# 99   color_intensity <= 3.14    alcohol <= 12.37  color_intensity <= 3.38
# 119  color_intensity <= 3.14    alcohol <= 12.37  color_intensity <= 3.38
# 101  color_intensity <= 3.14  malic_acid <= 1.56  color_intensity <= 3.09
# 108  color_intensity <= 3.14    alcohol <= 12.37  color_intensity <= 3.41
# 84   color_intensity <= 3.14    alcohol <= 12.37  color_intensity <= 3.38
# 90   color_intensity <= 3.14    alcohol <= 12.37  color_intensity <= 3.38
# 125  color_intensity <= 3.14    alcohol <= 12.37  color_intensity <= 3.38
# 97   color_intensity <= 3.14    alcohol <= 12.37  color_intensity <= 3.41
# 78          alcohol <= 12.37  malic_acid <= 1.56  color_intensity <= 3.41
# 102  color_intensity <= 3.14    alcohol <= 12.37  color_intensity <= 3.14
# 124  color_intensity <= 3.14    alcohol <= 12.37  color_intensity <= 3.38
# 122  color_intensity <= 3.14   proline <= 507.50  color_intensity <= 3.14
# 92   color_intensity <= 3.14  malic_acid <= 1.56  color_intensity <= 3.09
# 67          alcohol <= 12.37                           malic_acid <= 1.18
#
#               REASON2
# 87   alcohol <= 12.15
# 86   alcohol <= 12.23
# 113  alcohol <= 12.44
# 82   alcohol <= 12.44
# 117  alcohol <= 12.44
# 94   alcohol <= 12.23
# 99   alcohol <= 12.44
# 119  alcohol <= 12.06
# 101  alcohol <= 12.72
# 108  alcohol <= 12.23
# 84   alcohol <= 12.23
# 90   alcohol <= 12.44
# 125  alcohol <= 12.44
# 97   alcohol <= 12.44
# 78   alcohol <= 12.41
# 102  alcohol <= 12.41
# 124  alcohol <= 12.44
# 122  alcohol <= 12.44
# 92   alcohol <= 12.72
# 67   alcohol <= 12.41

# %% [markdown]
# ### For class 2

# %%
pe2l[['REASON1','REASON2']].join(
    pe2t[['REASON1','REASON2']], 
    lsuffix = '_LIME'
)
# Out:
#                              REASON1_LIME           REASON2_LIME  \
# 167  od280/od315_of_diluted_wines <= 1.82            hue <= 0.74
# 176  od280/od315_of_diluted_wines <= 1.82            hue <= 0.74
# 156  od280/od315_of_diluted_wines <= 1.82            hue <= 0.74
# 173  od280/od315_of_diluted_wines <= 1.82            hue <= 0.74
# 174  od280/od315_of_diluted_wines <= 1.82            hue <= 0.74
# 163  od280/od315_of_diluted_wines <= 1.82            hue <= 0.74
# 170                           hue <= 0.74     flavanoids <= 1.19
# 133  od280/od315_of_diluted_wines <= 1.82      malic_acid > 2.92
# 154  od280/od315_of_diluted_wines <= 1.82            hue <= 0.74
# 150  od280/od315_of_diluted_wines <= 1.82            hue <= 0.74
# 144                           hue <= 0.74     flavanoids <= 1.19
# 137  od280/od315_of_diluted_wines <= 1.82     flavanoids <= 1.19
# 166  od280/od315_of_diluted_wines <= 1.82     flavanoids <= 1.19
# 138  od280/od315_of_diluted_wines <= 1.82     flavanoids <= 1.19
# 130  od280/od315_of_diluted_wines <= 1.82  total_phenols <= 1.79
# 142                    flavanoids <= 1.19
# 161  od280/od315_of_diluted_wines <= 1.82     flavanoids <= 1.19
# 140                    flavanoids <= 1.19
# 141                           hue <= 0.74     flavanoids <= 1.19
# 143                    flavanoids <= 1.19
#
#                                   REASON1  \
# 167  od280/od315_of_diluted_wines <= 1.78
# 176  od280/od315_of_diluted_wines <= 1.78
# 156  od280/od315_of_diluted_wines <= 1.78
# 173  od280/od315_of_diluted_wines <= 1.78
# 174  od280/od315_of_diluted_wines <= 1.78
# 163  od280/od315_of_diluted_wines <= 1.78
# 170                           hue <= 0.74
# 133  od280/od315_of_diluted_wines <= 1.48
# 154                           hue <= 0.65
# 150  od280/od315_of_diluted_wines <= 1.53
# 144                           hue <= 0.74
# 137  od280/od315_of_diluted_wines <= 1.78
# 166  od280/od315_of_diluted_wines <= 1.78
# 138                    flavanoids <= 0.80
# 130  od280/od315_of_diluted_wines <= 1.48
# 142             0.52 < flavanoids <= 0.56
# 161                    flavanoids <= 0.80
# 140                    flavanoids <= 0.52
# 141                           hue <= 0.74
# 143                    flavanoids <= 0.81
#
#                                   REASON2
# 167                           hue <= 0.74
# 176                           hue <= 0.65
# 156                           hue <= 0.65
# 173                           hue <= 0.74
# 174                           hue <= 0.74
# 163                           hue <= 0.74
# 170  od280/od315_of_diluted_wines <= 1.88
# 133                           hue <= 0.78
# 154  od280/od315_of_diluted_wines <= 1.59
# 150                           hue <= 0.63
# 144                    flavanoids <= 0.80
# 137                    flavanoids <= 0.80
# 166                color_intensity > 7.57
# 138  od280/od315_of_diluted_wines <= 1.88
# 130                           hue <= 0.77
# 142  od280/od315_of_diluted_wines <= 2.10
# 161  od280/od315_of_diluted_wines <= 1.92
# 140                    0.77 < hue <= 0.77
# 141                    flavanoids <= 0.80
# 143  od280/od315_of_diluted_wines <= 2.10
